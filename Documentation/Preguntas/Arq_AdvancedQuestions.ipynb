# %% [markdown]
# 1.- Snowflake separates storage and compute. How does this architecture allow independent scaling for high‑concurrency workloads?

# %% [markdown]
# 2.- Which Snowflake service manages metadata, query optimization, authentication, and transaction consistency?

# %% [markdown]
# 3.- A Resource Monitor is configured with a credit quota and a “Suspend Immediately” action. What happens when the credit threshold is reached?

# %% [markdown]
# 4.- What is the main operational difference between manual clustering and automatic clustering?

# %% [markdown]
# 5.- In what scenario might manual clustering provide better performance than automatic clustering?

# %% [markdown]
# 6.- Why do virtual warehouses not share caches across warehouses, even when accessing the same data?

# %% [markdown]
# 7.- What does a fully-qualified Snowflake object name consist of, and which parts are mandatory?

# %% [markdown]
# 8.- Explain how schema-level security helps limit blast radius during privilege grants.

# %% [markdown]
# 9.- What is the key difference between permanent and transient tables regarding Fail‑safe?

# %% [markdown]
# 10.- Why might temporary tables reduce storage costs in long-running ETL pipelines?

# %% [markdown]
# 11.- Can a transient table be cloned with full Time Travel history?

# %% [markdown]
# 12.- If a table has a Time Travel retention of 1 day, but a user drops it, how long is the table recoverable?

# %% [markdown]
# 13.- Why can Fail‑safe recovery only be performed by Snowflake and not customers?

# %% [markdown]
# 14.- Does extending Time Travel retention increase query performance impact?

# %% [markdown]
# 15.- How does Snowflake ensure a Secure View protects underlying query logic?

# %% [markdown]
# 16.- Why do Materialized Views incur additional storage costs?

# %% [markdown]
# 17.- Which type of view is most appropriate for low-latency dashboards with repeatable queries over large stable datasets?

# %% [markdown]
# 18.- What limitation applies to Materialized Views regarding base table columns?

# %% [markdown]
# 19.- Can a Materialized View be created on top of another Materialized View?

# %% [markdown]
# 20.- When using Secure Views, what is a potential performance drawback?
